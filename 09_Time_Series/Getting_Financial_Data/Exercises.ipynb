# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
ticker = "AAPL"
start_date = "2015-01-01"
end_date = "2025-02-23"

data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Step 3. Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %% [markdown]
# ### Step 4. Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
df = pd.DataFrame(data)
test = df
test.columns = test.columns.get_level_values(0)

df_apple = test
df_apple.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Date
# 2015-01-02  24.320433  24.789802  23.879981  24.778679  212818400
# 2015-01-05  23.635288  24.169168  23.448431  24.089086  257142000
# 2015-01-06  23.637506  23.897772  23.274912  23.699792  263188400
# 2015-01-07  23.968966  24.069067  23.735393  23.846617  160423600
# 2015-01-08  24.889896  24.947734  24.180281  24.298181  237458000

# %% [markdown]
# ### Step 5. Add a new column "stock" to the dataframe and add the ticker symbol

# %%
df_apple['stock'] = 'AAPL'
df_apple.head()
# Out:
# Price           Close       High        Low       Open     Volume stock
# Date
# 2015-01-02  24.320433  24.789802  23.879981  24.778679  212818400  AAPL
# 2015-01-05  23.635288  24.169168  23.448431  24.089086  257142000  AAPL
# 2015-01-06  23.637506  23.897772  23.274912  23.699792  263188400  AAPL
# 2015-01-07  23.968966  24.069067  23.735393  23.846617  160423600  AAPL
# 2015-01-08  24.889896  24.947734  24.180281  24.298181  237458000  AAPL

# %% [markdown]
# ### Step 6. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
 df_tesla = yf.download('TSLA',start=start_date,end=end_date,multi_level_index=False)
 df_ibm = yf.download('IBM',start=start_date,end=end_date,multi_level_index=False)
 df_microsoft = yf.download('MSFT',start=start_date,end=end_date,multi_level_index=False)
 df_tesla['stock'] = 'TSLA'
df_ibm['stock'] = 'IBM'
df_microsoft['stock'] = 'MSFT'
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Step 7. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %%
frames = [df_apple,df_tesla,df_ibm,df_microsoft]
df = pd.concat(frames)
df
# Out:
#                  Close        High         Low        Open     Volume stock
# Date
# 2015-01-02   24.320433   24.789802   23.879981   24.778679  212818400  AAPL
# 2015-01-05   23.635288   24.169168   23.448431   24.089086  257142000  AAPL
# 2015-01-06   23.637506   23.897772   23.274912   23.699792  263188400  AAPL
# 2015-01-07   23.968966   24.069067   23.735393   23.846617  160423600  AAPL
# 2015-01-08   24.889896   24.947734   24.180281   24.298181  237458000  AAPL
# ...                ...         ...         ...         ...        ...   ...
# 2025-02-14  407.612671  408.091721  405.067786  406.973967   22758500  MSFT
# 2025-02-18  408.820282  409.778352  405.686551  407.183549   21423100  MSFT
# 2025-02-19  413.940002  414.658563  406.834255  407.063806   24114200  MSFT
# 2025-02-20  416.130005  419.309998  412.540009  415.290009   23508700  MSFT
# 2025-02-21  408.209991  418.049988  407.890015  417.339996   27448200  MSFT
#
# [10200 rows x 6 columns]

# %% [markdown]
# ### Step 8. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %%
df.set_index('stock',append=True,inplace=True)
df.head()
# Out:
#                       Close       High        Low       Open     Volume
# Date       stock
# 2015-01-02 AAPL   24.320433  24.789802  23.879981  24.778679  212818400
# 2015-01-05 AAPL   23.635288  24.169168  23.448431  24.089086  257142000
# 2015-01-06 AAPL   23.637506  23.897772  23.274912  23.699792  263188400
# 2015-01-07 AAPL   23.968966  24.069067  23.735393  23.846617  160423600
# 2015-01-08 AAPL   24.889896  24.947734  24.180281  24.298181  237458000

# %% [markdown]
# ### Step 7. Create a dataFrame called vol, with the volume values.

# %%
vol = df['Volume']
vol
# Out:
# Date        stock
# 2015-01-02  AAPL     212818400
# 2015-01-05  AAPL     257142000
# 2015-01-06  AAPL     263188400
# 2015-01-07  AAPL     160423600
# 2015-01-08  AAPL     237458000
#                        ...
# 2025-02-14  MSFT      22758500
# 2025-02-18  MSFT      21423100
# 2025-02-19  MSFT      24114200
# 2025-02-20  MSFT      23508700
# 2025-02-21  MSFT      27448200
# Name: Volume, Length: 10200, dtype: int64

# %% [markdown]
# ### Step 8. Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
date = vol.index.get_level_values(0)
date = pd.DatetimeIndex(date)

# %%
#vol = vol.reset_index()

#vol['Week'] = date.isocalendar().week.values

# vol = vol.set_index(['Date','stock'])
# vol['Year'] = date.year

# pd.pivot_table(vol, values='Volume', index=['Year','Week'],
#                columns=['stock'], aggfunc='sum')
# alternative way
gp = vol.groupby(by=['Year','Week','stock'])['Volume'].sum().unstack()
gp
# Out:
# stock            AAPL       IBM       MSFT       TSLA
# Year Week
# 2015 1      212818400   5779673   27913900   71466000
#      2     1133010000  25578884  158825300  340644000
#      3     1216906400  24329751  157088200  461988000
#      4      794948000  32682062  137352600  243175500
#      5     1863370800  34442689  437786800  235803000
# ...               ...       ...        ...        ...
# 2025 4      277129600  15594300   87828300  255401900
#      5      372790500  39049000  171530600  356730900
#      6      227383400  30149900  101724500  356244100
#      7      226587600  19898100  104730400  459159800
#      8      166463000  18532200   96494200  238479300
#
# [530 rows x 4 columns]

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
vol.head()
# Out:
#                      Volume  Week  Year
# Date       stock
# 2015-01-02 AAPL   212818400     1  2015
# 2015-01-05 AAPL   257142000     2  2015
# 2015-01-06 AAPL   263188400     2  2015
# 2015-01-07 AAPL   160423600     2  2015
# 2015-01-08 AAPL   237458000     2  2015

# %%
vol_2015 = vol[vol['Year'] == 2015]

gp_2015 = vol_2015.groupby(by=['Year','stock'])['Volume'].sum().unstack()
gp_2015
# Out:
# stock         AAPL         IBM        MSFT         TSLA
# Year
# 2015   52264199600  1156439400  9059455900  16323267000
